# %% [markdown]
# # Welcome to the start of your adventure in Agentic AI

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Are you ready for action??</h2>
#             <span style="color:#ff7800;">Have you completed all the setup steps in the <a href="../setup/">setup</a> folder?<br/>
#             Have you read the <a href="../README.md">README</a>? Many common questions are answered here!<br/>
#             Have you checked out the guides in the <a href="../guides/01_intro.ipynb">guides</a> folder?<br/>
#             Well in that case, you're ready!!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">This code is a live resource - keep an eye out for my updates</h2>
#             <span style="color:#00bfff;">I push updates regularly. As people ask questions or have problems, I add more examples and improve explanations. As a result, the code below might not be identical to the videos, as I've added more steps and better comments. Consider this like an interactive book that accompanies the lectures.<br/><br/>
#             I try to send emails regularly with important updates related to the course. You can find this in the 'Announcements' section of Udemy in the left sidebar. You can also choose to receive my emails via your Notification Settings in Udemy. I'm respectful of your inbox and always try to add value with my emails!
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### And please do remember to contact me if I can help
#
# And I love to connect: https://www.linkedin.com/in/eddonner/
#
#
# ### New to Notebooks like this one? Head over to the guides folder!
#
# Just to check you've already added the Python and Jupyter extensions to Cursor, if not already installed:
# - Open extensions (View >> extensions)
# - Search for python, and when the results show, click on the ms-python one, and Install it if not already installed
# - Search for jupyter, and when the results show, click on the Microsoft one, and Install it if not already installed
# Then View >> Explorer to bring back the File Explorer.
#
# And then:
# 1. Click where it says "Select Kernel" near the top right, and select the option called `.venv (Python 3.12.12)` or similar, which should be the first choice or the most prominent choice. You may need to choose "Python Environments" first.
# 2. Click in each "cell" below, starting with the cell immediately below this text, and press Shift+Enter to run
# 3. Enjoy!
#
# After you click "Select Kernel", if there is no option like `.venv (Python 3.12.12)` then please do the following:
# 1. On Mac: From the Cursor menu, choose Settings >> VS Code Settings (NOTE: be sure to select `VSCode Settings` not `Cursor Settings`);
# On Windows PC: From the File menu, choose Preferences >> VS Code Settings(NOTE: be sure to select `VSCode Settings` not `Cursor Settings`)
# 2. In the Settings search bar, type "venv"
# 3. In the field "Path to folder with a list of Virtual Environments" put the path to the project root, like C:\Users\username\projects\agents (on a Windows PC) or /Users/username/projects/agents (on Mac or Linux).
# And then try again.

# %%
# First let's do an import. If you get an Import Error, see Q5 and then Q25 here: https://edwarddonner.com/avatar

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %% [markdown]
# ### Wait, did that just output `False`??
#
# If so, the most common reason is that you didn't save your `.env` file after adding the key! Be sure to have saved.
#
# Also, make sure the `.env` file is named precisely `.env` and is in the project root directory (`agents`)
#
# By the way, your `.env` file might have a stop symbol next to it in Cursor on the left, and that's actually a good thing: that's Cursor saying to you, "hey, I realize this is a file filled with secret information, and I'm not going to send it to an external AI to suggest changes, because your keys should not be shown to anyone else."

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Final reminders</h2>
#             <span style="color:#ff7800;">1. If you're not confident about Environment Variables or Web Endpoints / APIs, please read Topics 3 and 5 in this <a href="../guides/04_technical_foundations.ipynb">technical foundations guide</a>.<br/>
#             2. If you want to use AIs other than OpenAI, like Gemini, DeepSeek or Ollama (free), please see the first section in this <a href="../guides/09_ai_apis_and_ollama.ipynb">AI APIs guide</a>.<br/>
#             3. If you ever get a Name Error in Python, you can always fix it immediately; see the last section of this <a href="../guides/06_python_foundations.ipynb">Python Foundations guide</a> and follow both tutorials and exercises.<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Check the key - if you're not using OpenAI, check whichever key you're using! Ollama doesn't need a key.

import os
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:8]}")
else:
    print("OpenRouter API Key not set - please head to the troubleshooting guide in the setup folder")
# Out:
# OpenRouter API Key exists and begins sk-or-v1

# %%
# And now - the all important import statement
# If you get an import error - head over to Q5 and Q25 in the FAQ at https://edwarddonner.com/avatar
# Even for other LLM providers like Gemini, you still use this OpenAI import - see Guide 9 for why

from openai import OpenAI

# %%
# And now we'll create an instance of the OpenAI class
# If you're not sure what it means to create an instance of a class - head over to the guides folder (guide 6)!
# If you get a NameError - head over to the guides folder (guide 6)to learn about NameErrors - always instantly fixable
# If you're not using OpenAI, you just need to slightly modify this - precise instructions are in the AI APIs guide (guide 9)
openrouter_api_key = os.getenv("OPENROUTER_API_KEY")
openai = OpenAI(base_url="https://openrouter.ai/api/v1", api_key=openrouter_api_key)

# %%
# Create a list of messages in the familiar OpenAI format

messages = [{"role": "user", "content": "Tell me a fun fact"}]

# %%
messages
# Out:
# [{'role': 'user', 'content': 'Tell me a fun fact'}]

# %%
# And now call it! Any problems, head to the troubleshooting guide
# This uses GPT 5.4 nano, an incredibly cheap model
# The APIs guide (guide 9) has exact instructions for using even cheaper or free alternatives to OpenAI
# If you get a NameError, head to the guides folder (guide 6) to learn about NameErrors - always instantly fixable

response = openai.chat.completions.create(model="openrouter/free", messages=messages)
print(response.choices[0].message.content)
# Out:
# Here's a fun fact for you:
# **Octopuses have three hearts!** Two pump blood to their gills, and one sends it to the rest of the body. But here's the twist: when they swim, the main heart (the one serving the body) *stops beating* to conserve energy. That’s why octopuses usually prefer crawling instead of swimming—it’s less tiring!
#
# Bonus: Their blood is blue because they use a copper-based protein called *hemocyanin* instead of the iron-based hemoglobin in humans. 🐙💙

# %%
# And now - let's ask for a question:

question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
# ask it - this uses GPT 5.4 mini, still cheap but more powerful than nano

response = openai.chat.completions.create(model="openrouter/free", messages=messages)
question = response.choices[0].message.content
print(question)
# Out:
# A sequence of numbers follows a specific logical rule: 2, 9, 28, 65, 126,... What is the next number in the sequence, and what is the mathematical formula used to derive each term $n$?

# %%
# form a new messages list

messages = [{"role": "user", "content": question}]
messages
# Out:
# [{'role': 'user',
#   'content': 'A sequence of numbers follows a specific logical rule: 2, 9, 28, 65, 126,... What is the next number in the sequence, and what is the mathematical formula used to derive each term $n$?'}]

# %%
# Ask the model to answer the hard question

response = openai.chat.completions.create(model="openrouter/free", messages=messages)
answer = response.choices[0].message.content
print(answer)
# Out:
# The next number in the sequence is **217**.
#
# The mathematical formula for the $n$-th term is:
#
# $$a_n = n^3 + 1$$
#
# ### Derivation:
# Let's examine the relationship between the term position ($n$) and the value:
#
# | $n$ (Position) | $n^3$ | Sequence Value ($n^3 + 1$) |
# | :--- | :--- | :--- |
# | 1 | $1^3 = 1$ | **2** |
# | 2 | $2^3 = 8$ | **9** |
# | 3 | $3^3 = 27$ | **28** |
# | 4 | $4^3 = 64$ | **65** |
# | 5 | $5^3 = 125$ | **126** |
# | **6** | **$6^3 = 216$** | **217** |
#
# Each term is simply the cube of its position index ($n$) plus 1.

# %%
from IPython.display import Markdown, display

display(Markdown(answer))
# Out:
# The next number in the sequence is **217**.
#
# The mathematical formula for the $n$-th term is:
#
# $$a_n = n^3 + 1$$
#
# ### Derivation:
# Let's examine the relationship between the term position ($n$) and the value:
#
# | $n$ (Position) | $n^3$ | Sequence Value ($n^3 + 1$) |
# | :--- | :--- | :--- |
# | 1 | $1^3 = 1$ | **2** |
# | 2 | $2^3 = 8$ | **9** |
# | 3 | $3^3 = 27$ | **28** |
# | 4 | $4^3 = 64$ | **65** |
# | 5 | $5^3 = 125$ | **126** |
# | **6** | **$6^3 = 216$** | **217** |
#
# Each term is simply the cube of its position index ($n$) plus 1.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A sequence of numbers follows a specific logical rule: 2, 9, 28, 65, 126,... What is the next number in the sequence, and what is the mathematical formula used to derive each term $n$?
#
# And here is a possible answer that might be correct or incorrect:
# The next number in the sequence is **217**.
#
# The mathematical formula for the $n$-th term is:
#
# $$a_n = n^3 + 1$$
#
# ### Derivation:
# Let's examine the relationship between the term position ($n$) and the value:
#
# | $n$ (Position) | $n^3$ | Sequence Value ($n^3 + 1$) |
# | :--- | :--- | :--- |
# | 1 | $1^3 = 1$ | **2** |
# | 2 | $2^3 = 8$ | **9** |
# | 3 | $3^3 = 27$ | **28** |
# | 4 | $4^3 = 64$ | **65** |
# | 5 | $5^3 = 125$ | **126** |
# | **6** | **$6^3 = 216$** | **217** |
#
# Each term is simply the cube of its position index ($n$) plus 1.
#
# Please evaluate if the answer is correct or incorrect.

# %%
message = f"""
Here is a question:
{question}

And here is a possible answer that might be correct or incorrect:
{answer}

Please evaluate if the answer is correct or incorrect.
"""

print(message)
# Out:
# Here is a question:
# A sequence of numbers follows a specific logical rule: 2, 9, 28, 65, 126,... What is the next number in the sequence, and what is the mathematical formula used to derive each term $n$?
#
# And here is a possible answer that might be correct or incorrect:
# The next number in the sequence is **217**.
#
# The mathematical formula for the $n$-th term is:
#
# $$a_n = n^3 + 1$$
#
# ### Derivation:
# Let's examine the relationship between the term position ($n$) and the value:
#
# | $n$ (Position) | $n^3$ | Sequence Value ($n^3 + 1$) |
# | :--- | :--- | :--- |
# | 1 | $1^3 = 1$ | **2** |
# | 2 | $2^3 = 8$ | **9** |
# | 3 | $3^3 = 27$ | **28** |
# | 4 | $4^3 = 64$ | **65** |
# | 5 | $5^3 = 125$ | **126** |
# | **6** | **$6^3 = 216$** | **217** |
#
# Each term is simply the cube of its position index ($n$) plus 1.
#
# Please evaluate if the answer is correct or incorrect.

# %%
messages = [{"role": "user", "content": message}]
response = openai.chat.completions.create(model="openai/gpt-oss-20b:free", messages=messages)
print(response.choices[0].message.content)
# Out:
# Thehofptth sequence
#
# \[
# 2,\;9,\;28,\;65,\;126,\dots
# \]
#
# matches the formula
#
# \[
# a_n=n^3+1, \qquad n=1,2,3,\dots
# \]
#
# because
#
# | \(n\) | \(n^3\) | \(n^3+1\) |
# |-------|--------|----------|
# | 1 | 1 | 2 |
# | 2 | 8 | 9 |
# | 3 | 27 | 28 |
# | 4 | 64 | 65 |
# | 5 | 125 | 126 |
#
# Thus the **next term** for \(n=6\) is
#
# \[
# a_6 = 6^3+1 = 216+1 = \boxed{217}.
# \]
#
# So the proposed answer is correct: the next number is 217, and each term is the cube of its position index plus one.

# %% [markdown]
# # Congratulations!
#
# That was a small, simple step in the direction of Agentic AI, with your new environment!
#
# Next time things get more interesting...

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Now try this commercial application:<br/>
#             First ask the LLM to pick a business area that might be worth exploring for an Agentic AI opportunity.<br/>
#             Then ask the LLM to present a pain-point in that industry - something challenging that might be ripe for an Agentic solution.<br/>
#             Finally have 3 third LLM call propose the Agentic AI solution. <br/>
#             We will cover this at up-coming labs, so don't worry if you're unsure.. just give it a try!
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# First create the messages:

messages = [{"role": "user", "content": "Pick a business area that might be worth exploring for an Agentic AI oportunity"}]

# Then make the first call:
response = openai.chat.completions.create(model="openrouter/free", messages=messages)

# Then read the business idea:
business_area = response.choices[0].message.content
print(business_area)

# And repeat! In the next message, include the business area within the message
messages.append({"role": "assistant", "content": business_area})
messages.append({"role": "user", "content": "present a pain-point in that industry - something challenging that might be ripe for an Agentic solution"})

response = openai.chat.completions.create(model="openrouter/free", messages=messages)
challenge = response.choices[0].message.content
print(challenge)

messages.append({"role": "assistant", "content": challenge})
messages.append({"role": "user", "content": "Propose the Agentic AI solution"})

response = openai.chat.completions.create(model="openrouter/free", messages=messages)
print(response.choices[0].message.content)
# Out:
# One business area that is exceptionally ripe for an **Agentic AI** opportunity is **B2B Supply Chain & Procurement Coordination** (specifically, disruption management and "tail-spend" procurement for mid-market manufacturers and distributors).
#
# Here is a breakdown of why this area is worth exploring, what the agentic opportunity looks like, and how it would create value.
#
# ---
#
# ### 1. The Business Area: Autonomous Supply Chain & Logistics Orchestration
# Supply chain management is fundamentally about coordinating fragmented data, external vendors, and physical goods. Today, this is largely a manual, reactive process handled by procurement managers buried in emails, spreadsheets, and ERP screens.
#
# ### 2. The Problem (Why it’s Broken Today)
# * **Fragmented Communication:** Critical updates (delayed shipments, customs holds, material shortages) come via unstructured emails, PDFs, or phone calls.
# * **Reactive Firefighting:** By the time a delay is noticed, it has already cascaded into a production line stoppage or a missed customer deadline.
# * **High Labor Cost:** Skilled supply chain analysts spend up to 70% of their time on data entry and status chasing rather than strategic sourcing.
# * **Long Tail Spend:** Small, urgent purchases (MRO supplies, one-off components) are often ignored by traditional automation because they are too variable, leading to maverick spend.
#
# ### 3. The Agentic AI Opportunity
# Instead of a simple "chatbot" or "dashboard," an **Agentic Supply Chain Orchestrator** would act as a semi-autonomous operations manager. It would use LLMs for comprehension (reading supplier emails) and traditional automation/APIs for action (updating ERPs, sending POs).
#
# **What the Agent would do autonomously:**
# * **Monitor & Predict:** Continuously scan weather APIs, geopolitical news, and supplier portals. If a typhoon is predicted near a key port, the agent predicts a 5-day delay.
# * **Act & Rebook:** The agent identifies an alternative regional supplier via a connected marketplace API, compares lead times and cost against the original PO, and—if within pre-set authority limits—automatically issues a new purchase order and cancels the old one.
# * **Communicate & Resolve:** The agent drafts and sends a polite email to the freight forwarder requesting a revised ETA, logs the interaction in the ERP (e.g., NetSuite or SAP), and posts a Slack update to the sales team: *"Shipment #1234 delayed; rerouted via air freight, arriving Tuesday. Customer notified."*
# * **Reconcile:** When the invoice arrives, the agent matches it against the PO and delivery receipt, flags discrepancies (e.g., a surprise fuel surcharge), and either auto-approves or escalates to a human.
#
# ### 4. Example Agentic Workflow
# 1. **Trigger:** Agent detects a supplier email stating a raw material batch failed QC.
# 2. **Analysis:** Agent checks current inventory levels and production schedules.
# 3. **Planning:** Agent identifies that without this material, Plant B stops in 48 hours.
# 4. **Action:** Agent queries 3 pre-vetted alternate suppliers, finds one with stock, negotiates via a structured API/chat, and places an emergency order using a "contingency budget" authority.
# 5. **Handoff:** If the cost exceeds $10k, the agent pauses and sends a concise summary to the human procurement lead for a one-click approval, rather than handling the whole thread itself.
#
# ### 5. Why This is Ripe for Agentic AI *Now*
# * **Tool Use:** Modern ERPs and freight platforms (Flexport, Project44) have robust APIs, allowing agents to *do* things, not just talk.
# * **Economic Pressure:** Margin compression is forcing mid-market firms to do more with fewer ops staff.
# * **Model Capability:** Multimodal LLMs can now accurately read messy supplier invoices, packing slips, and even interpret a handwritten note on a bill of lading.
#
# ### 6. Risks & Human-in-the-Loop Considerations
# * **Authority Limits:** Agents should only autonomously commit spend up to a certain threshold (e.g., $5k) or within a pre-approved supplier list.
# * **Hallucination in Compliance:** Agents must not falsify customs documents or regulatory compliance claims; these require human sign-off.
# * **Vendor Relationships:** Over-automating communications can annoy long-term suppliers; the agent’s tone and frequency need careful tuning.
#
# ---
#
# ### Alternative Areas Worth a Look:
# If supply chain doesn't fit your interest, two other high-potential **Agentic AI** business areas are:
# 1. **Healthcare Revenue Cycle Management (Prior Authorization):** Agents that autonomously navigate payer portals, fill forms, and appeal denied claims.
# 2. **B2B Sales Research & Outbound GTM:** Agents that research a prospect’s tech stack, identify a use-case, write personalized outreach, and book meetings without a human SDR touching it until the call.
#
# **Supply Chain Orchestration**, however, offers the cleanest mix of clear ROI (reduced stockouts/expedite fees) and tangible autonomous action.
#
#
# **Business Area:** **Healthcare Supply Chain Management**
#
# **Pain Point:**
# In healthcare, managing the supply chain for critical medical supplies (e.g., PPE, vaccines, specialized pharmaceuticals) is a high-stakes, hyper-complex challenge. Hospitals and clinics often face:
# - **Unpredictable Demand**: Sudden surges during outbreaks or emergencies (e.g., pandemics) strain inventory and procurement.
# - **Fragmented Coordination**: Multiple stakeholders (suppliers, hospitals, logistics providers) operate with siloed systems, leading to delays, stockouts, or overstocking.
# - **Regulatory Compliance**: Strict regulations around temperature-controlled logistics (cold chain) and tracking of expiration dates increase operational risk.
# - **Cost Inefficiencies**: Traditional reactive procurement models waste resources and miss opportunities to negotiate bulk pricing or prioritize urgent needs.
#
# **Why Agentic AI Could Work Here:**
# An Agentic AI solution could autonomously:
# 1. **Predict Demand**: Analyze real-time data (e.g., infection trends, hospital admissions) to forecast surges and pre-position supplies.
# 2. **Optimize Procurement**: Dynamically negotiate with suppliers, prioritize orders based on urgency, and adjust pricing strategies.
# 3. **Manage Logistics**: Coordinate cold-chain shipping routes dynamically to avoid delays or spoilage, even with last-minute changes.
# 4. **Ensure Compliance**: Automatically validate regulations during transit (e.g., temperature monitoring) and flag risks in real time.
#
# **Key Advantage:**
# Agentic AI could act proactively in a chaotic environment, reducing human error and saving lives by ensuring critical supplies reach providers when and where they’re needed most.
#
# ## 1️⃣ Business Area – **Supply‑Chain Disruption Management (SCDM)**
#
# Global supply chains are increasingly complex: dozens‑hundreds of suppliers spread across continents, volatile raw‑material prices, geopolitical events, climate‑driven logistics hiccups, and massive data‑silodness. Companies struggle to **anticipate, respond, and recover** from disruptions, often reacting too late or with overly‑broad “just‑in‑case” inventory that ties up cash.
#
# ---
#
# ## 2️⃣ Pain‑Point – “The Silent Bleeding of Cash & Service”
#
# | Symptom | Business Impact |
# |---------|-----------------|
# | **Late‑stage detection** – disruptions are noticed only after shipments are delayed or stockouts appear. | Revenue loss, missed customer commitments, expedited freight costs (often 3‑10× normal rates). |
# | **Manual, fragmented monitoring** – teams scan news feeds, ERP alerts, and supplier portals separately, each with different terminology and confidence levels. | High labor cost (often 30‑40 FTEs in large enterprises) and decision fatigue; critical signals are missed. |
# | **Inflexible response plans** – pre‑defined “run‑the‑numbers” procedures can’t adapt to novel events (e.g., new trade restrictions, natural disasters, supplier bankruptcy). | Over‑reliance on static buffers, excess safety stock, and costly ad‑hoc sourcing. |
# | **Poor cross‑functional coordination** – procurement, logistics, inventory planners, and finance operate on disparate dashboards, leading to inconsistent actions. | Duplicate effort, conflicting decisions, and slow recovery. |
# | **Limited visibility beyond tier‑1 suppliers** – disruptions upstream (tier‑2/3) cascade downstream but are invisible until they hit tier‑1 deliveries. | Cascading failures, expensive “fire‑fighting” and loss of SLA guarantees. |
#
# **Quantified impact (industry averages)**
#
# * **$1.5 T** annual loss globally from supply‑chain disruptions (McKinsey, 2023).
# * **30‑50 %** of that loss could be recovered with predictive, autonomous mitigation (according to Gartner’s “Predictive Supply‑Chain Initiative” report).
# * Companies that invest in automated disruption response see **15‑25 % reduction** in inventory carrying cost while maintaining service levels (MIT Sloan, 2022).
#
# The problem is ripe for an **Agentic AI** because it requires:
#
# * **Continuous perception** of a dynamic, multi‑modal environment (weather, geopolitical alerts, supplier health, transport capacity).
# * **Planning** of alternative actions (reroute, re‑stock, negotiate with backup suppliers).
# * **Autonom ous execution** of those actions (auto‑generate purchase orders, update logistics plans, trigger budget reallocations).
# * **Learning** from each incident to improve future predictions.
#
# ---
#
# ## 3️⃣ Proposed Agentic AI Solution – **“SupplyChain‑Sentinel”**
#
# A **multi‑agent system** that operates as an autonomous “digital Operations Center” for supply‑chain risk and mitigation.
#
# ### Core Architecture
# | Agent | Primary Responsibility |
# |-------|--------------------------|
# | **Signal‑Ingestion Agent** | Pulls real‑time data from news APIs, weather services, satellite imagery, customs filings, ERP/PLM, IoT sensor streams, supplier portals, and ESG/credit‑risk databases. |
# | **Risk‑Scoring Agent** | Applies a hybrid model (graph‑based causal reasoning + deep time‑series forecasting) to assign probability & severity scores to each potential disruption. |
# | **Scenario‑Planner Agent** | Generates a short‑term (3‑30 days) “what‑if” simulation using Monte‑Carlo and constraint‑programming to evaluate alternative plans (e.g., switch carriers, back‑order with alternate supplier, increase safety stock at a secondary warehouse). |
# | **Action‑Execution Agent** | Directly interacts with enterprise systems (ERP, TMS, WMS, procurement platforms) to instantiate the chosen plan – e.g., create a purchase requisition, update a transport order, adjust inventory counts. |
# | **Learning‑Feedback Agent** | Captures actual outcomes, compares them to predicted impacts, and updates model parameters (reinforcement‑learning loop) to improve future scores and plans. |
# | **Human‑In‑The‑Loop (HITL) Agent** | Provides a “trust‑layer” – presents recommended actions to planners with explainability, confidence scores, and the option to approve, modify, or reject. |
#
# All agents communicate via a **domain‑aware knowledge graph** that tracks entities (suppliers, nodes, shipments, inventory) and relationships (contracts, lead‑times, risk exposures). The graph also serves as a single source of truth for explainability.
#
# ---
#
# ## 4️⃣ Key Features
#
# | Feature | Description | Value |
# |---------|-------------|-------|
# | **Unified Signal Hub** | Consolidates 30+ external data streams + internal ERP/PLM data into a continuous stream. | Eliminates data silos; reduces detection lag from days to minutes. |
# | **Causal Risk Scoring** | Combines news sentiment analysis, supply‑chain network topology, and historical disruption patterns. | More accurate predictions (AUC ≈ 0.85 vs. 0.65 for simpleforecast). |
# | **Dynamic “What‑If” Sandbox** | Allows planners to explore “run the numbers” for multiple mitigation options in seconds. | Faster decision cycles; reduces over‑reliance on static safety stock. |
# | **Zero‑Touch Execution** | Autonomously creates purchase orders, re‑routes shipments, or adjusts inventory levels when confidence > 90 % and no conflicting human override. | Cuts manual process time by 70‑90 %; accelerates recovery. |
# | **Explainability & Trust Dashboard** | Shows why a disruption was flagged, what the optimal actions are, confidence scores, and impact forecasts. | Increases adoption; satisfies audit/compliance requirements. |
# | **Continuous Learning Loop** | Reinforcement‑learning updates model parameters after each real‑world event. | Improves accuracy over time; adapts to new risk patterns (e.g., emerging geopolitical tensions). |
# | **Scalable Integration** | Plug‑in connectors for SAP, Oracle, Coupa, Fleetboard, SAP TMS, and major cloud logistics APIs. | Works across multi‑ERP, multi‑region enterprises. |
# | **Compliance & Governance Layer** | Enforces SOC 2, GDPR, and data‑privacy rules; logs all automated actions for audit. | Reduces regulatory risk. |
#
# ---
#
# ## 5️⃣ Implementation Roadmap (24‑Month Horizon)
#
# | Phase | Duration | Core Activities | Deliverable |
# |-------|----------|----------------|------------|
# | **0️⃣ Foundations** | 0‑2 mo | Define data‑ownership model, onboard key suppliers to shared data exchange (API/SFTP), set up knowledge‑graph schema. | Data‑governance charter + graph blueprint. |
# | **1️⃣ Ingestion & Baseline Modeling** | 2‑5 mo | Build Signal‑Ingestion Agent, connect to weather, news, customs, IoT sensors; train initial risk‑scoring model on historic disruptions. | Real‑time signal pipeline + risk‑score prototype (AUC ≈ 0.70). |
# | **2️⃣ Scenario & Execution Engine** | 5‑9 mo | Develop Scenario‑Planner Agent (Monte‑Carlo + constraint solver); integrate Action‑Execution Agent with ERP/TMS via RPA/API calls; create HITL dashboard. | End‑to‑end sandbox + automated order‑creation capability. |
# | **3️⃣ Learning & Optimization** | 9‑15 mo | Launch Feedback Agent, set up RL loops, add anomaly detection for “black‑swans,” run A/B tests on mitigation actions. | Continuous‑learning model (AUC ≈ 0.85, 20 % improvement in mitigation success). |
# | **4️⃣ Scale & Governance** | 15‑21 mo | Expand to tier‑2/3 suppliers, add compliance‑first logging, achieve SOC 2 Type II audit readiness, create KPI dashboard for execs. | Production‑ready, audited system. |
# | **5️⃣ Manage & Refine** | 21‑24 mo | Ongoing performance monitoring, model drift detection, add new risk domains (e.g., cyber‑risk to supply chain), pilot in secondary product line. | Sustained ROI, roadmap for next‑gen extensions. |
#
# ---
#
# ## 6️⃣ Expected Business Impact (Quantitative)
#
# | Metric | Baseline (pre‑solution) | Target after 12 months | % Improvement |
# |--------|------------------------|-----------------------|---------------|
# | **Average disruption detection time** | 48 h | 15 min | **~97 %** |
# | **Revenue loss due to disruptions** | $12 M/yr (example firm) | $8 M/yr | **33 %** |
# | **Safety‑stock level** | 30 days of inventory | 18 days | **40 %** cash saved |
# | **Manual mitigation effort (FTEs)** | 12 FTEs | 3 FTEs | **75 %** labor reduction |
# | **Innovation cycles (time to explore new mitigation scenario)** | 2‑3 weeks | <24 h | **>90 %** speed‑up |
# | **Compliance audit exceptions** | 10 % of actions | <1 % | **90 %** reduction |
#
# ---
#
# ## 7️⃣ Quick “Why This is a Great Agentic‑AI Opportunity”
#
# * **Autonomous decision making** – The system can *act* on data, not just advise (e.g., auto‑reorder, reroute).
# * **Multi‑modal perception** – Pulls together structured ERP data + unstructured news/satellite feeds, a hallmark of true agents.
# * **Dynamic replanning** – disruptions evolve quickly; the planner agent continuously re‑evaluates options.
# * **Cross‑functional coordination** – Breaks the silo between procurement, logistics, and finance by acting on a shared knowledge graph.
# * **Scalable governance** – Built‑in audit logs and human‑in‑the‑loop controls satisfy enterprise compliance while still delivering speed.
#
# ---
#
# ### TL;DR
#
# **Business area:** Supply‑Chain Disruption Management
# **Pain point:** Late detection, fragmented monitoring, inflexible response plans, high manual effort, and hidden upstream risks → billions in waste.
# **Solution:** *SupplyChain‑Sentinel*, a multi‑agent platform that ingests global & internal signals, scores risk in real time, runs instant “what‑if” simulations, and autonomously executes mitigation (re‑routing, re‑stocking, alternate sourcing) while continuously learning and providing explainable, auditable actions.
#
# Implementing this Agentic AI can cut disruption impact by up to one‑third, free up dozens of FTEs, and reduce safety‑stock carrying costs by 40 %—all while keeping service levels intact.
#
# **Ready to explore a pilot?** I can walk you through data‑source mapping, prototype the risk‑scoring agent, and outline a short‑term ROI model for a specific product line or geography.

# %%
"""Author: Abrahim Mejía Valdez - Software Engineer"""

import os
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

load_dotenv()

endpoint = os.getenv("AZURE_FOUNDRY_ENDPOINT")
model_name = "gpt-5-nano"
api_key = os.getenv("AZURE_FOUNDRY_API_KEY")
max_tokens = 2500

if not endpoint or not api_key:
    raise EnvironmentError(
        "Missing AZURE_FOUNDRY_ENDPOINT or AZURE_FOUNDRY_API_KEY"
    )

try:
    # Create the client
    client = OpenAI(base_url=endpoint, api_key=api_key)

    # Setting up instructions for the agent and first prompt
    messages = [
        {
            "role": "system",
            "content": "You are an AI engineer with expertise in developing and maintaining enterprise-grade applications.",
        },
        {
            "role": "user",
            "content": "Pick a business area that might be worth exploring for an Agentic AI opportunity. Generate text only output with a max of 100 chars.",
        },
    ]

    # Then first call
    response = client.chat.completions.create(
        model=model_name, messages=messages, max_completion_tokens=max_tokens
    )

    # Then read the business idea
    business_area = response.choices[0].message.content
    print(f"Business area: {business_area}")

    # Include the business area within the message as well as the previous messages

    messages.extend(
        [
            {"role": "assistant", "content": business_area},
            {
                "role": "user",
                "content": "Present a pain-point in that industry - something challenging that might be ripe for an Agentic solution. No more than 200 chars.",
            },
        ]
    )

    # Request the agent for the pain-point
    response = client.chat.completions.create(
        model=model_name, messages=messages, max_completion_tokens=max_tokens
    )

    challenge = response.choices[0].message.content
    print(f"Challenge: {challenge}")

    messages.extend(
        [
            {"role": "assistant", "content": challenge},
            {
                "role": "user",
                "content": """
                    Propose the Agentic AI solution with the following rules:
                    - Use markdown format
                    - 500 chars at most
                    - It MUST have a title section, an introduction, the core idea and why it is a good Agentic solution
                    """,
            },
        ]
    )
    # Request the agent for the solution
    response = client.chat.completions.create(model=model_name, messages=messages)
    solution = response.choices[0].message.content

    print("Solution:\n" + solution)
    display(Markdown(solution))
except Exception as ex:
    print(f"An error has occurred:\n {ex}")
# Out:
# Business area: Autonomous AI for healthcare ops and patient flow optimization.
# Challenge: Siloed data and manual handoffs impede fast triage, bed management, and discharge planning, fueling ED overcrowding.
# Solution:
# # Agentic AI for Hospital Patient Flow
# ## Introduction
# Hospitals suffer from siloed data and slow handoffs, driving delays.
# ## Core Idea
# An agentic AI ingests EHR, bed status, staffing, and discharge data to autonomously triage, assign beds, coordinate transfers, and plan discharges, with human oversight.
# ## Why it's worth for Agentic solution
# Reduces delays, lowers length of stay, and frees clinicians for care. Provides auditable, policy-adherent actions and scalable ops.
# # Agentic AI for Hospital Patient Flow
# ## Introduction
# Hospitals suffer from siloed data and slow handoffs, driving delays.
# ## Core Idea
# An agentic AI ingests EHR, bed status, staffing, and discharge data to autonomously triage, assign beds, coordinate transfers, and plan discharges, with human oversight.
# ## Why it's worth for Agentic solution
# Reduces delays, lowers length of stay, and frees clinicians for care. Provides auditable, policy-adherent actions and scalable ops.
